# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakkar99/BDA594-Sarthak_Kar/blob/main/House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d286e065-51c6-4246-95f0-33bc24b56ae3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d286e065-51c6-4246-95f0-33bc24b56ae3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0   0         34291             24        1        0      47     35693
# 1   1         95145             60        0        1      60     34773
# 2   2         92661             45        1        1      62     45457
# 3   3         97184             99        0        0      59     15113
# 4   4         61752            100        0        0      57     64245
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              2              1  2000           0                  1
# 1              1              4  2000           0                  1
# 2              4              8  2020           1                  1
# 3              1              1  2000           0                  1
# 4              8              4  2018           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# ...

# %%
len(df)
# Out:
# 22730

# %%
df.columns
# Out:
# Index(['id', 'squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price'],
#       dtype='object')

# %%
dict1={}
dict2={}
select_columns=[]
str_columns=[]
for column in df.columns:
  dict1[column]=df[column].nunique()
  dict2[column]=df[column].dtypes
  if df[column].dtypes != 'O':
    select_columns.append(column)
  else:
    str_columns.append(column)
print(dict1)
print(dict2)
select_columns
# Out:
# {'id': 22730, 'squareMeters': 7319, 'numberOfRooms': 100, 'hasYard': 2, 'hasPool': 2, 'floors': 101, 'cityCode': 7810, 'cityPartRange': 10, 'numPrevOwners': 10, 'made': 33, 'isNewBuilt': 2, 'hasStormProtector': 2, 'basement': 4903, 'attic': 5167, 'garage': 896, 'hasStorageRoom': 2, 'hasGuestRoom': 11, 'price': 7421}
# {'id': dtype('int64'), 'squareMeters': dtype('int64'), 'numberOfRooms': dtype('int64'), 'hasYard': dtype('int64'), 'hasPool': dtype('int64'), 'floors': dtype('int64'), 'cityCode': dtype('int64'), 'cityPartRange': dtype('int64'), 'numPrevOwners': dtype('int64'), 'made': dtype('int64'), 'isNewBuilt': dtype('int64'), 'hasStormProtector': dtype('int64'), 'basement': dtype('int64'), 'attic': dtype('int64'), 'garage': dtype('int64'), 'hasStorageRoom': dtype('int64'), 'hasGuestRoom': dtype('int64'), 'price': dtype('float64')}
# ['id',
#  'squareMeters',
#  'numberOfRooms',
#  'hasYard',
#  'hasPool',
#  'floors',
#  'cityCode',
#  'cityPartRange',
#  'numPrevOwners',
# ...

# %%
str_columns
# Out:
# []

# %%
import pandas as pd

# Assuming str_columns is a list of column names with string values
df1 = df.copy()  # Create a copy of the original DataFrame

for column in str_columns:
    unique_values = df1[column].unique()  # Get unique values in the column
    mapping = {value: index for index, value in enumerate(unique_values)}  # Create a mapping from string to integer
    df1[column] = df1[column].map(mapping)  # Use map to replace string values with integers

df1
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0          0         34291             24        1        0      47     35693
# 1          1         95145             60        0        1      60     34773
# 2          2         92661             45        1        1      62     45457
# 3          3         97184             99        0        0      59     15113
# 4          4         61752            100        0        0      57     64245
# ...      ...           ...            ...      ...      ...     ...       ...
# 22725  22725         55825             84        1        0      70     12031
# 22726  22726         65870             88        1        0      49     23197
# 22727  22727         93192             42        1        0      39      8539
# 22728  22728         65797             86        1        0      89     23197
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %%
df1
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0          0         34291             24        1        0      47     35693
# 1          1         95145             60        0        1      60     34773
# 2          2         92661             45        1        1      62     45457
# 3          3         97184             99        0        0      59     15113
# 4          4         61752            100        0        0      57     64245
# ...      ...           ...            ...      ...      ...     ...       ...
# 22725  22725         55825             84        1        0      70     12031
# 22726  22726         65870             88        1        0      49     23197
# 22727  22727         93192             42        1        0      39      8539
# 22728  22728         65797             86        1        0      89     23197
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %%
df_filtered=df[select_columns]
df_filtered
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0          0         34291             24        1        0      47     35693
# 1          1         95145             60        0        1      60     34773
# 2          2         92661             45        1        1      62     45457
# 3          3         97184             99        0        0      59     15113
# 4          4         61752            100        0        0      57     64245
# ...      ...           ...            ...      ...      ...     ...       ...
# 22725  22725         55825             84        1        0      70     12031
# 22726  22726         65870             88        1        0      49     23197
# 22727  22727         93192             42        1        0      39      8539
# 22728  22728         65797             86        1        0      89     23197
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %%
select_columns
# Out:
# ['id',
#  'squareMeters',
#  'numberOfRooms',
#  'hasYard',
#  'hasPool',
#  'floors',
#  'cityCode',
#  'cityPartRange',
#  'numPrevOwners',
#  'made',
#  'isNewBuilt',
#  'hasStormProtector',
#  'basement',
#  'attic',
#  'garage',
#  'hasStorageRoom',
#  'hasGuestRoom',
#  'price']

# %%
df2 = df1.copy()

for column in df1.columns:
    q2 = df2[column].quantile(0.90)  # 90th percentile
    q1 = df2[column].quantile(0.10)
    df2 = df2[(df2[column] <= q2) & (df2[column]>=q1)]   # Remove values above the 90th percentile
df2
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 2281    2281         51744             83        0        1      37     30135
# 2299    2299         19572             86        0        0      28     59407
# 2317    2317         49617             56        0        0      50     86885
# 2319    2319         46131             38        1        0      29     83019
# 2326    2326         29570             47        0        1      18     52085
# ...      ...           ...            ...      ...      ...     ...       ...
# 20391  20391         50589             57        0        1      55     20554
# 20410  20410         70898             24        0        0      35     12334
# 20428  20428         32527             35        0        0      50     62591
# 20452  20452         62166             36        0        1      52     16730
# 20453  20453         57970             73        0        1      53     52920
#
# ...

# %%
# # df_filtered=df[select_columns]
# # #df=df_filtered
# #df1
# df2=df1.copy()
# columns=df1.columns
# for column in columns:
#   q2 = df2[column].quantile(0.90)
#   q1 = df2[column].quantile(0.10) #removing outliers
#   df2=df2[(df1[column] < q2) & (df2[column] > q1)]

# %%
df2
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 2281    2281         51744             83        0        1      37     30135
# 2299    2299         19572             86        0        0      28     59407
# 2317    2317         49617             56        0        0      50     86885
# 2319    2319         46131             38        1        0      29     83019
# 2326    2326         29570             47        0        1      18     52085
# ...      ...           ...            ...      ...      ...     ...       ...
# 20391  20391         50589             57        0        1      55     20554
# 20410  20410         70898             24        0        0      35     12334
# 20428  20428         32527             35        0        0      50     62591
# 20452  20452         62166             36        0        1      52     16730
# 20453  20453         57970             73        0        1      53     52920
#
# ...

# %%
df_filtered=df_filtered[df['numberOfRooms']>=df['floors']] #removiving the building having number of floors > rooms

# %%
df2
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 2281    2281         51744             83        0        1      37     30135
# 2299    2299         19572             86        0        0      28     59407
# 2317    2317         49617             56        0        0      50     86885
# 2319    2319         46131             38        1        0      29     83019
# 2326    2326         29570             47        0        1      18     52085
# ...      ...           ...            ...      ...      ...     ...       ...
# 20391  20391         50589             57        0        1      55     20554
# 20410  20410         70898             24        0        0      35     12334
# 20428  20428         32527             35        0        0      50     62591
# 20452  20452         62166             36        0        1      52     16730
# 20453  20453         57970             73        0        1      53     52920
#
# ...

# %%
#df_filtered=df2.drop(['ADDRESS','POSTED_BY'],axis=1)

# %%
# df_filtered=df_filtered[df['numberOfRooms']<=10] #only building with less tahn 10 rooms can be house

# %%
df_filtered
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 1          1         95145             60        0        1      60     34773
# 3          3         97184             99        0        0      59     15113
# 4          4         61752            100        0        0      57     64245
# 5          5         30300             36        0        0      35     19069
# 6          6         19341             95        1        0      37     23939
# ...      ...           ...            ...      ...      ...     ...       ...
# 22720  22720         60886             17        0        0       5     28735
# 22724  22724         13073             81        0        1      69     42152
# 22725  22725         55825             84        1        0      70     12031
# 22726  22726         65870             88        1        0      49     23197
# 22727  22727         93192             42        1        0      39      8539
#
# ...

# %%
df_filtered.isna().sum()
# Out:
# id                   0
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %%
dict1={}
dict1=df_filtered.corr()
dict1
# Out:
#                          id  squareMeters  numberOfRooms   hasYard   hasPool  \
# id                 1.000000     -0.000767       0.002188 -0.008792 -0.001227
# squareMeters      -0.000767      1.000000       0.041479 -0.009514 -0.011935
# numberOfRooms      0.002188      0.041479       1.000000 -0.018412 -0.017593
# hasYard           -0.008792     -0.009514      -0.018412  1.000000 -0.060859
# hasPool           -0.001227     -0.011935      -0.017593 -0.060859  1.000000
# floors            -0.004520      0.021541       0.519280 -0.004657 -0.024643
# cityCode           0.012457      0.019893      -0.022960  0.001149  0.019886
# cityPartRange      0.019097      0.007793       0.005774  0.009283 -0.009622
# numPrevOwners     -0.001281      0.000018       0.014821  0.002235  0.001091
# made              -0.010495      0.012639      -0.000776  0.009166 -0.008506
# isNewBuilt         0.011881      0.007033      -0.012661 -0.001079  0.029425
# ...

# %%
val=sorted(dict1['TARGET(PRICE_IN_LACS)'],reverse=True)
val

# %%
import seaborn as sns
# sns.pairplot(df_filtered)

# %%
sns.distplot(df2['price'],bins=24)

# %%
dict1=df_filtered.corr()

# %%
dict1['']

# %%
df2['price'].skew()

# %%
df2['log_price']=np.log(df2['price'])
#np.log(data['Price'])

# %%
# val=sorted(dict1['price'],reverse=True)[2:9]
# val

# %%
df2

# %%
df2=df2.drop('price',axis=1)

# %%
df2

# %%
print(df2['log_price'].skew())
sns.distplot(df2['log_price'])

# %%
# from numpy.lib.function_base import select #selecting the top features in colleration to price
# select_column=[]
# for column1 in dict1.keys():
#   if dict1[column1]['price'] in val:
#     select_column.append(column1)

# %%
# select_column

# %%
import seaborn as sns

# %%
target= df2['log_price']
select_columns=list(df2.columns)
select_columns.pop()
print(target.head())
select_columns

# %%
X= df2[select_columns]
y=df2['log_price']

print(X.head())

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()#heatmap
model.fit(X,target)

# %%
sns.heatmap(df.corr(),cmap="coolwarm")

# %%
#Train, Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=101) #dividing into traintest split

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)

# %%
print(model.intercept_)

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df

# %%
predictions = model.predict(X_test)
import matplotlib.pyplot as plt

# %%
print(len(X_train),len(X_test),len(y_train),len(y_test))

# %%
plt.scatter(model.predict(X_test),y_test) #scatter model
#plt.plot(X,model.predict(X),alpha=0.7,color='red',linewidth=4)

# %%
# plt.scatter(y,m,alpha=0.3)
plt.plot(y_test,model.predict(X_test),alpha=0.7,color='red',linewidth=4)
plt.xlabel("Y Test Vaues") #regression line
plt.ylabel("Model predicted values")

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
from sklearn.metrics import accuracy_score
X_val=model.predict(X_test)
X_val

# %%
y_val=[]
for cal in y_test:
  y_val.append(cal)
y_val

# %%
from sklearn.metrics import r2_score #accuracy caluculator
score = r2_score(y_val, X_val)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
